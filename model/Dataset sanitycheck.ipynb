# %% [markdown]
# # Dataset sanitycheck

# %%
# %load_ext autoreload
# %autoreload 2

from dataset import MidiDataset
import random
from config import *
from utils import tensor_to_midi

# %%
dataset = MidiDataset(midi_dir=r"C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\maestro-v3.0.0", 
                      metadata_csv_path=r"C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\maestro-midi_tempos.csv",
                      num_bars=NUM_BARS,
                      steps_per_bar=STEPS_PER_BAR,
                      verbose=True)
# Out:
# Found 1276 MIDI files.
# Processing MIDI files, normalizing tempo, and extracting segments...
# Processing files: 100%|██████████| 1276/1276 [02:47<00:00,  7.63it/s]
# Successfully extracted 525067 segments from 1276 files.

# %%
for i in range(10):
    random_num = random.randint(0, len(dataset)-1)
    pianoroll, bpm, filepath = dataset[random_num]
    print(f"Visualizing {filepath}")
    print(f"Tensor shape: {pianoroll.shape}")
    dataset.visualize(pianoroll)
    tensor_to_midi(pianoroll, output_path=f"dataset_sanitycheck/processed_file_{i}.mid", bpm=80)
# Out:
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\maestro-v3.0.0\MIDI-Unprocessed_Recital5-7_MID--AUDIO_06_R1_2018_wav--1.midi
# Tensor shape: torch.Size([64, 36])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_0.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\maestro-v3.0.0\MIDI-Unprocessed_052_PIANO052_MID--AUDIO-split_07-06-17_Piano-e_3-03_wav--2.midi
# Tensor shape: torch.Size([64, 36])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_1.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\maestro-v3.0.0\MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_01_Track01_wav.midi
# Tensor shape: torch.Size([64, 36])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_2.mid...
# MIDI file saved successfully.
# ...
