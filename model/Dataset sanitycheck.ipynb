# %% [markdown]
# # Dataset sanitycheck

# %%
# %load_ext autoreload
# %autoreload 2

from dataset import MidiDataset
import random
from config import *
from utils import tensor_to_midi
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataset = MidiDataset(midi_dir=r"C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty", 
                      metadata_csv_path=r"C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\midi_metadata_dla_3_instrumentow.csv",
                      num_bars=NUM_BARS,
                      steps_per_bar=STEPS_PER_BAR,
                      verbose=True)
# Out:
# Found 4084 MIDI files.
# Processing MIDI files, normalizing tempo, and extracting segments...
# Processing files: 100%|██████████| 4084/4084 [06:47<00:00, 10.03it/s]
# Successfully extracted 268555 segments from 4084 files.

# %%
for i in range(100):
    random_num = random.randint(0, len(dataset)-1)
    pianoroll, bpm, filepath = dataset[random_num]
    print(f"Visualizing {filepath}")
    print(f"Bpm {bpm}")
    print(f"Tensor shape: {pianoroll.shape}")
    dataset.visualize(pianoroll)
    tensor_to_midi(pianoroll, output_path=f"dataset_sanitycheck/processed_file_{i}.mid")
# Out:
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\8555eb4baef17bc9ca56b349d6367bb7.mid
# Bpm 120.0
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_0.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\c4899716e1c3a8fc41e4eaad4c2bf040.mid
# Bpm 170.00009155273438
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_1.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\1d2e6f34ef31d22ab709e0aa8931b89b.mid
# Bpm 130.00013732910156
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_2.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\5349286fcdb701d83490f9a245618433.mid
# Bpm 130.00013732910156
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_3.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\dd1446f48d2edd5b3f8be62243c0ef35.mid
# Bpm 168.00039672851562
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_4.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\4ec32a58c52cbfe4e4a4bebf5391f71e.mid
# Bpm 125.0
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_5.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\73cb9699ffdf9215ba0f4cdc5e45389b.mid
# Bpm 120.0
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_6.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\5d1bb06308800cfd900a103c5e32f011.mid
# Bpm 75.99996948242188
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_7.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\188599a7a79fe14f082e7ef83100851b.mid
# Bpm 100.0
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_8.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\6f658be71c0f9f2b437629e4a579846d.mid
# Bpm 254.00050354003906
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_9.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\6f658be71c0f9f2b437629e4a579846d.mid
# Bpm 254.00050354003906
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_10.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\3179ed793144dabec96f075aa88d6a51.mid
# Bpm 98.99993896484375
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_11.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\c7a17fa29a93d2dd295de3053410d392.mid
# Bpm 175.0000762939453
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_12.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\070a2d2f662e1a22ce8e026d8882ef25.mid
# Bpm 115.00003051757812
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_13.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\5ac8ed0e071b84ea7bd2f528c8f50347.mid
# Bpm 100.0
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_14.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\2521faae87cb0fe713109052aa32b613.mid
# Bpm 165.99989318847656
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_15.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\ba34c088376a2b71b0648d4bc5e29949.mid
# Bpm 250.0
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_16.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\c87292a2b10e362916682f413115c885.mid
# Bpm 195.0001983642578
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_17.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\59bfd1993104685a2d1079abdb355b35.mid
# Bpm 68.99993896484375
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_18.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\b3eac449b00777ccc59669a7e6d7a643.mid
# Bpm 126.00012969970703
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_19.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\186dcf9d3b5a5e913aa26f1549fd5fab.mid
# Bpm 125.0
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_20.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\4faa6bae7d46658a6edefc561b450c04.mid
# Bpm 120.0
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_21.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\84f87554f152888889a577d82bab1b41.mid
# Bpm 120.0
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_22.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\15c365537ab957c225499be9c948541a.mid
# Bpm 254.00050354003906
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_23.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\c724f1e99ef2744e60ecfbad850ac9ff.mid
# Bpm 134.00006103515625
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_24.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\c54f0c897be2121de09f567b246b8821.mid
# Bpm 120.0
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_25.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\cb0599747ef2c48c2b54d6a7a9d1c334.mid
# Bpm 250.0
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_26.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\134372801a8eecfbbbc44bd51cd90a1b.mid
# Bpm 158.00035095214844
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file
mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\821dafeca1ab87af2fdc244184fe132c.mid
# Bpm 120.0
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_65.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\a34459638895bf96bfc56cd59c9800b0.mid
# Bpm 122.99996948242188
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_66.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\ae26256182c0157c7748d83e88cac1dc.mid
# Bpm 135.00013732910156
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_67.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\a3e497910670d330ae1e8fe8246d2a4c.mid
# Bpm 100.0
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_68.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\17e4cef68a01268df73062423159d9af.mid
# Bpm 107.99991607666016
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_69.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\61f4b9057227dd58cd80a588025841b0.mid
# Bpm 162.0001678466797
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_70.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\1fdc8c4b9be8d1392bb0f33d8d7830d0.mid
# Bpm 75.0
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_71.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\fd4a5b8a805d40a7b62cd8c00f76556a.mid
# Bpm 80.0
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_72.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\a4c96eea36ec6f89e8b52fcd1659adc8.mid
# Bpm 128.0
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_73.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\eb59ee6c4eac35e3b60718fc7f3fc407.mid
# Bpm 120.0
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_74.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\da762ae8d62024a82eb219b08d19637f.mid
# Bpm 170.00009155273438
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_75.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\d1ec2c0e09bb79c52a7d45474e0ce5f5.mid
# Bpm 115.00003051757812
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_76.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\f3e6c68e0ef8f8676ea9d8a32ead0a36.mid
# Bpm 100.0
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_77.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\ed8afc712f3629dae57abf1cb92f0535.mid
# Bpm 115.00003051757812
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_78.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\d44156bc0d3bc440a4a534ae52a0c445.mid
# Bpm 107.99991607666016
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_79.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\dd1e093f98ac2d39cc023c20d3b801b2.mid
# Bpm 186.0003662109375
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_80.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\ade22ee4b811ee89a1725594740a5f0f.mid
# Bpm 85.00004577636719
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_81.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\a20336672f11531e2697f3fe97c58e76.mid
# Bpm 80.90003967285156
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_82.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\ba34c088376a2b71b0648d4bc5e29949.mid
# Bpm 250.0
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_83.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\1279d0826bde3ffdf3723658b4442fd8.mid
# Bpm 196.00157165527344
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_84.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\6ff6015b661bf78ec8bc5b9d2f24ce18.mid
# Bpm 200.0
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_85.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\e0e6f33b74341d04b8eab411b691ce29.mid
# Bpm 150.0
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_86.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\788fac488b0b5acb067f374d545e946b.mid
# Bpm 5760.0
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_87.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\d7bc1bad991f2ce2af66efb8f51650be.mid
# Bpm 109.0001449584961
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_88.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\8750811d6dd5417a09c3e9e908d92605.mid
# Bpm 155.00030517578125
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_89.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\a9ba01f0a084a3dbd78b0527c3433bff.mid
# Bpm 100.0
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_90.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\13961551d4646f14e636d65b4aacba13.mid
# Bpm 126.00012969970703
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_91.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\b785a6d324a3cee1a39e1051c893b427.mid
# Bpm 106.00013732910156
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_92.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\d256f5b72aaebee0bdd99601263e953a.mid
# Bpm 125.0
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_93.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\48a6b0f29c9770396a61212123606f7c.mid
# Bpm 225.0005645751953
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_94.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\c71b48a91ea5709138d37a6533b16900.mid
# Bpm 137.00006103515625
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_95.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\09ab3f0eb16507f44b48da821f51d2ed.mid
# Bpm 140.00013732910156
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_96.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\f478f7a62006a5b935cc05a103f11a44.mid
# Bpm 134.00006103515625
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_97.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\7e3387854c307f4761963d3427e18d85.mid
# Bpm 115.00201416015625
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_98.mid...
# MIDI file saved successfully.
# Visualizing C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\dataset\transformed_dataset_3_imnstrumenty\a7abe10a7d369381081b001e49b91cfb.mid
# Bpm 109.0001449584961
# Tensor shape: torch.Size([128, 128])
# Converting tensor to MIDI file at dataset_sanitycheck/processed_file_99.mid...
# MIDI file saved successfully.
