# %%
# %load_ext autoreload
# %autoreload 2

import torch
from model import LofiModel
from model.config_finetuning import *
from finetune import run_finetune
print(torch.__version__)
print(torch.version.cuda)
# Out:
# 2.7.1+cu118
# 11.8

# %% [markdown]
# # Finetuning

# %%
run_finetune(experiment_name="Second finetuning try - prioritize latent more")
# Out:
# Creating model instance...
# Loading pre-trained weights from C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\model\checkpoints\finetuned_lofi_model\lofi_model_epoch_165.pth...
# Successfully loaded weights from C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\model\checkpoints\finetuned_lofi_model\lofi_model_epoch_165.pth
# Using device: cuda
#
# Loading dataset...
# Found 9274 MIDI files.
# Processing MIDI files and extracting segments...
# Processing files: 100%|██████████| 9274/9274 [00:15<00:00, 596.77it/s]
# Successfully extracted 7437 segments from 9274 files.
# Splitting dataset...
# Dataset split into: Train=6321, Validation=1116
# Finished preparing dataset.
#
# Calculating class weights...
# Analyzing dataset for weights: 100%|██████████| 198/198 [00:01<00:00, 181.72it/s]
# Calculated class weights: [0.002900568535551429, 0.9056090116500854, 0.09149037301540375]
# Encoder layers are FROZEN. Training only the decoder.
# ...
