# %%
# %load_ext autoreload
# %autoreload 2

import torch
from model import LofiModel
from finetune_config import *
from finetune import run_finetune
print(torch.__version__)
print(torch.version.cuda)
# Out:
# 2.7.1+cu118
# 11.8

# %% [markdown]
# # Finetuning

# %%
run_finetune(experiment_name="Finetuning lofi piano model")
# Out:
# Creating model instance...
# Loading pre-trained weights from C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\model\checkpoints\final_pretrained_model\checkpoints\lofi_model_epoch_320.pth...
# Successfully loaded weights from C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\model\checkpoints\final_pretrained_model\checkpoints\lofi_model_epoch_320.pth
# Using device: cuda
#
# Loading dataset...
# Found 2291 MIDI files.
# Processing MIDI files and extracting segments...
# Processing files: 100%|██████████| 2291/2291 [00:05<00:00, 425.31it/s]
# Successfully extracted 1853 segments from 2291 files.
# Splitting dataset...
# Dataset split into: Train=1575, Validation=278
# Finished preparing dataset.
#
# Calculating class weights...
# Analyzing dataset for weights: 100%|██████████| 50/50 [00:00<00:00, 152.72it/s]
# Calculated class weights: [0.0028789369389414787, 0.9063583016395569, 0.09076280146837234]
# Encoder layers are FROZEN. Training only the decoder.
# ...
