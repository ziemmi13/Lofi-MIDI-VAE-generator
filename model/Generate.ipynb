# %%
import torch
from model import LofiModel
from dataset_finetuning import MidiDataset
from model.config_finetuning import *
print(torch.__version__)
print(torch.version.cuda)
# Out:
# 2.7.1+cu118
# 11.8

# %% [markdown]
# ## Generation

# %%
model = LofiModel()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 

for epoch in range(5):
    print(f"Epoch: {epoch}")
    model.load_weights(fr"C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\model\checkpoints\finetuned_lofi_model\lofi_model_epoch_15.pth")
    generated = model.generate(output_path=f"generated/lofi_model/generated_finetuned_lofi_model_epoch_165.mid")
    MidiDataset.visualize(generated, title="Generated", show_plot=True)
# Out:
# Epoch: 0
# Successfully loaded weights from C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\model\checkpoints\finetuned_lofi_model\lofi_model_epoch_15.pth
# Converting tensor to MIDI file at generated/lofi_model/generated_finetuned_lofi_model_epoch_165.mid...
# MIDI file saved successfully.
# Epoch: 1
# Successfully loaded weights from C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\model\checkpoints\finetuned_lofi_model\lofi_model_epoch_15.pth
# Converting tensor to MIDI file at generated/lofi_model/generated_finetuned_lofi_model_epoch_165.mid...
# MIDI file saved successfully.
# Epoch: 2
# Successfully loaded weights from C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\model\checkpoints\finetuned_lofi_model\lofi_model_epoch_15.pth
# Converting tensor to MIDI file at generated/lofi_model/generated_finetuned_lofi_model_epoch_165.mid...
# MIDI file saved successfully.
# Epoch: 3
# ...
