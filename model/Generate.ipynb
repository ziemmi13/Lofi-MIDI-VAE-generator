# %%
import torch
from model import LofiModel
from dataset import MidiDataset
from config import *
print(torch.__version__)
print(torch.version.cuda)
# Out:
# 2.7.1+cu118
# 11.8

# %% [markdown]
# ## Generation

# %%
model = LofiModel()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 

for i in range(5):
    model.load_weights(fr"C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\model\checkpoints\lofi_model_epoch_120.pth")
    generated = model.generate(output_path=f"generated/generated_{i}.mid")
    MidiDataset.visualize(generated, title="Generated", show_plot=True)
# Out:
# Successfully loaded weights from C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\model\checkpoints\lofi_model_epoch_120.pth
# Converting tensor to MIDI file at generated/generated_0.mid...
# MIDI file saved successfully.
# Successfully loaded weights from C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\model\checkpoints\lofi_model_epoch_120.pth
# Converting tensor to MIDI file at generated/generated_1.mid...
# MIDI file saved successfully.
# Successfully loaded weights from C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\model\checkpoints\lofi_model_epoch_120.pth
# Converting tensor to MIDI file at generated/generated_2.mid...
# MIDI file saved successfully.
# Successfully loaded weights from C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\model\checkpoints\lofi_model_epoch_120.pth
# Converting tensor to MIDI file at generated/generated_3.mid...
# MIDI file saved successfully.
# ...
