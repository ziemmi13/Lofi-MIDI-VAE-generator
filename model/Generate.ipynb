# %%
import torch
from train import train
from model import LofiModel
from dataset import MidiDataset
import pretty_midi
import numpy as np
from config import *
print(torch.__version__)
print(torch.version.cuda)
# Out:
# 2.7.1+cu118
# 11.8
# c:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\venv\Lib\site-packages\pretty_midi\instrument.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# ## Generation

# %%
model = LofiModel()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 

for epoch in range(10, 201, 10):
    print(f"Epoch: {epoch}")
    model.load_weights(fr"C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\model\checkpoints\lofi_model_epoch_{epoch}.pth")
    generated = model.generate(output_path=f"generated/generated_{epoch}.mid")
    MidiDataset.visualize(generated, title="Generated", show_plot=True)
# Out:
# Epoch: 10
# Successfully loaded weights from C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\model\checkpoints\lofi_model_epoch_10.pth
# Converting tensor to MIDI file at generated/generated_10.mid...
# MIDI file saved successfully.
# Epoch: 20
# Successfully loaded weights from C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\model\checkpoints\lofi_model_epoch_20.pth
# Converting tensor to MIDI file at generated/generated_20.mid...
# MIDI file saved successfully.
# Epoch: 30
# Successfully loaded weights from C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\model\checkpoints\lofi_model_epoch_30.pth
# Converting tensor to MIDI file at generated/generated_30.mid...
# MIDI file saved successfully.
# Epoch: 40
# Successfully loaded weights from C:\Users\Hyperbook\Desktop\STUDIA\SEM III\PZ#2\model\checkpoints\lofi_model_epoch_40.pth
# Converting tensor to MIDI file at generated/generated_40.mid...
# MIDI file saved successfully.
# Epoch: 50
# ...
